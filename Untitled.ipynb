# %%
import pandas as pd

# %%
df=pd.read_csv("Book1.csv")
df
del df[df.columns[0]]
df
# Out:
#                           County name Pop/mile2 Pop/km2
# 0           New York County, New York    69,468  26,822
# 1              Kings County, New York    35,369  13,656
# 2              Bronx County, New York    32,903  12,704
# 3             Queens County, New York    20,554   7,936
# 4    San Francisco County, California    17,179   6,633
# 5           Hudson County, New Jersey    13,732   5,302
# 6       Suffolk County, Massachusetts    12,417   4,794
# 7   Philadelphia County, Pennsylvania    11,379   4,394
# 8    Washington, District of Columbia     9,857   3,806
# 9                Alexandria, Virginia     9,314   3,596
# 10          Richmond County, New York     8,030   3,101
# 11         Arlington County, Virginia     7,994   3,086
# 12        City of Baltimore, Maryland     7,672   2,962
# 13           Essex County, New Jersey     6,212   2,398
# 14             Falls Church, Virginia     6,170   2,382
# 15            Manassas Park, Virginia     5,633   2,175
# ...
