# %%
import plotly.plotly as py
import plotly.tools as tls
import pandas as pd
import numpy as np
from pprint import pprint
import requests
import json

plotly.tools.set_credentials_file(username='yuh13',api_key='IzaMfeQ5hEi9FgiULxpT' )

# %%
dd = pd.read_csv("top_5_services.csv")
print(dd.columns)
dd['Provider State'] = dd['Provider State'].apply(lambda x: str(x))
dd.dtypes
# Out:
# Index(['Unnamed: 0', 'DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Hospital Referral Region Description',
#        ' Total Discharges ', ' Average Covered Charges ',
#        ' Average Total Payments ', 'Average Medicare Payments'],
#       dtype='object')
# Unnamed: 0                                int64
# DRG Definition                           object
# Provider Id                               int64
# Provider Name                            object
# Provider Street Address                  object
# Provider City                            object
# Provider State                           object
# Provider Zip Code                         int64
# Hospital Referral Region Description     object
#  Total Discharges                         int64
#  Average Covered Charges                float64
#  Average Total Payments                 float64
# Average Medicare Payments               float64
# dtype: object

# %%
df = dd.groupby('Provider State').mean().reset_index(inplace=False)
df.dtypes
# Out:
# Provider State                object
# Unnamed: 0                   float64
# Provider Id                  float64
# Provider Zip Code            float64
#  Total Discharges            float64
#  Average Covered Charges     float64
#  Average Total Payments      float64
# Average Medicare Payments    float64
# dtype: object

# %%
data = [dict(type='chloropleth', autocolorscale=False, 
             locations = df['Provider State'], z = df['Average Medicare Payments'],
            locationmode = "USA-states", text = dd['Provider Name'], colorscale = 'custom-colorscale', 
        colorbar=dict(title="Dollars"))]
data
# Out:
# [{'autocolorscale': False,
#   'colorbar': {'title': 'Dollars'},
#   'colorscale': 'custom-colorscale',
#   'locationmode': 'USA-states',
#   'locations': 0     AK
#   1     AL
#   2     AR
#   3     AZ
#   4     CA
#   5     CO
#   6     CT
#   7     DC
#   8     DE
#   9     FL
#   10    GA
#   11    HI
#   12    IA
#   13    ID
#   14    IL
#   15    IN
#   16    KS
#   17    KY
#   18    LA
#   19    MA
#   20    MD
#   21    ME
#   22    MI
#   23    MN
#   24    MO
#   25    MS
#   26    MT
#   27    NC
#   28    ND
#   29    NE
#   30    NH
#   31    NJ
#   32    NM
#   33    NV
#   34    NY
#   35    OH
#   36    OK
#   37    OR
#   38    PA
#   39    RI
#   40    SC
#   41    SD
#   42    TN
#   43    TX
#   44    UT
#   45    VA
#   46    VT
#   47    WA
#   48    WI
#   49    WV
#   50    WY
#   Name: Provider State, dtype: object,
#   'text': 0                                     DOMINICAN HOSPITAL
#   1                           MANCHESTER MEMORIAL HOSPITAL
#   2                                     MERCY HOSPITAL INC
#   3                         MUNROE REGIONAL MEDICAL CENTER
#   4                              LARKIN COMMUNITY HOSPITAL
#   5                                  CORAL GABLES HOSPITAL
#   6                              PALMETTO GENERAL HOSPITAL
#   7                          WEST KENDALL BAPTIST HOSPITAL
#   8                       SOUTHEAST ALABAMA MEDICAL CENTER
#   9                          MARSHALL MEDICAL CENTER SOUTH
#   10                        ELIZA COFFEE MEMORIAL HOSPITAL
#   11                              MIZELL MEMORIAL HOSPITAL
#   12                           CRENSHAW COMMUNITY HOSPITAL
#   13                         MARSHALL MEDICAL CENTER NORTH
#   14                                     ST VINCENT'S EAST
#   15                        DEKALB REGIONAL MEDICAL CENTER
#   16                      SOUTHWEST ALABAMA MEDICAL CENTER
#   17                         SHELBY BAPTIST MEDICAL CENTER
#   18                        HELEN KELLER MEMORIAL HOSPITAL
#   19                                   DALE MEDICAL CENTER
#   20                               CHEROKEE MEDICAL CENTER
#   21                          BAPTIST MEDICAL CENTER SOUTH
#   22                         JACKSON HOSPITAL & CLINIC INC
#   23                    GEORGE H. LANIER MEMORIAL HOSPITAL
#   24                                 ELBA GENERAL HOSPITAL
#   25                   EAST ALABAMA MEDICAL CENTER AND SNF
#   26                                      WEDOWEE HOSPITAL
#   27                        UNIVERSITY OF ALABAMA HOSPITAL
#   28                                COMMUNITY HOSPITAL INC
#   29                       CULLMAN REGIONAL MEDICAL CENTER
#                                 ...
#   14784                  ST CLARE'S HOSPITAL OF WESTON INC
#   14785       WHEATON FRANCISCAN HEALTHCARE- FRANKLIN, INC
#   14786                              AURORA MEDICAL CENTER
#   14787                  CAMPBELL COUNTY MEMORIAL HOSPITAL
#   14788                         SHERIDAN MEMORIAL HOSPITAL
#   14789                         RIVERTON MEMORIAL HOSPITAL
#   14790                           LANDER REGIONAL HOSPITAL
#   14791                MEMORIAL HOSPITAL SWEETWATER COUNTY
#   14792                             WYOMING MEDICAL CENTER
#   14793                   CHEYENNE REGIONAL MEDICAL CENTER
#   14794                          IVINSON MEMORIAL HOSPITAL
#   14795                   SOUTH HAMPTON COMMUNITY HOSPITAL
#   14796                            ST MARKS MEDICAL CENTER
#   14797                 METHODIST MANSFIELD MEDICAL CENTER
#   14798                       NORTH CYPRESS MEDICAL CENTER
#   14799                  ST LUKE'S PATIENTS MEDICAL CENTER
#   14800                  SCOTT & WHITE HOSPITAL-ROUND ROCK
#   14801                    SETON MEDICAL CENTER WILLIAMSON
#   14802                 CEDAR PARK REGIONAL MEDICAL CENTER
#   14803        TEXAS HEALTH PRESBYTERIAN HOSPITAL ROCKWALL
#   14804              SIERRA PROVIDENCE EAST MEDICAL CENTER
#   14805                                TRUSTPOINT HOSPITAL
#   14806                                   DOCTORS HOSPITAL
#   14807                      ST LUKE'S SUGAR LAND HOSPITAL
#   14808                       METHODIST STONE OAK HOSPITAL
#   14809                          SETON MEDICAL CENTER HAYS
#   14810         TEXAS REGIONAL MEDICAL CENTER AT SUNNYVALE
#   14811    TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
#   14812             ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
#   14813                    METHODIST WEST HOUSTON HOSPITAL
#   Name: Provider Name, Length: 14814, dtype: object,
#   'type': 'chloropleth',
#   'z': 0     8205.791515
#   1     3938.448954
#   2     4087.515885
#   3     5165.180637
#   4     6458.986326
#   5     4676.619639
#   6     5625.689667
#   7     6809.206286
#   8     4973.451481
#   9     4332.018853
#   10    4350.561622
#   11    6693.811667
#   12    4195.629182
#   13    4388.385400
#   14    4919.548986
#   15    4218.279269
#   16    4255.319453
#   17    4302.976285
#   18    4362.042242
#   19    5355.090105
#   20    6896.564424
#   21    4858.640000
#   22    4914.592245
#   23    4889.821857
#   24    4431.644678
#   25    4286.077357
#   26    4530.709592
#   27    4601.545961
#   28    4583.371290
#   29    4524.306374
#   30    4574.092308
#   31    5574.685981
#   32    5222.421860
#   33    4910.597980
#   34    6164.112570
#   35    4398.704858
#   36    4368.308333
#   37    5060.564855
#   38    4604.403127
#   39    5207.934902
#   40    4523.689275
#   41    4730.105652
#   42    4053.733348
#   43    4569.430996
#   44    4196.867767
#   45    4207.934078
#   46    6132.598571
#   47    5034.007175
#   48    4410.136300
#   49    4198.294645
#   50    6613.988537
#   Name: Average Medicare Payments, dtype: float64}]

# %%
layout = dict(title="State Average Hospital Charges", 
             geo = dict(scope='usa', projection=dict(type='albers usa'), 
                        showlakes = True, lakecolor = 'rgb(66,165,245)',),)
layout
# Out:
# {'geo': {'lakecolor': 'rgb(66,165,245)',
#   'projection': {'type': 'albers usa'},
#   'scope': 'usa',
#   'showlakes': True},
#  'title': 'State Average Hospital Charges'}

# %%
fig = dict(data=data, layout=layout)
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# PlotlyDataTypeError                       Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1453         try:
# -> 1454             graph_objs.Figure(figure)
#    1455         except exceptions.PlotlyError as err:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#    1173     def __init__(self, *args, **kwargs):
# -> 1174         super(Figure, self).__init__(*args, **kwargs)
#    1175         if 'data' not in self:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __setitem__(self, key, value, _raise)
#     431         if self._get_attribute_role(key) == 'object':
# --> 432             value = self._value_to_graph_object(key, value, _raise=_raise)
#     433             if not isinstance(value, (PlotlyDict, PlotlyList)):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in _value_to_graph_object(self, key, value, _raise)
#     542         return GraphObjectFactory.create(key, value, _raise=_raise,
# --> 543                                          _parent=self, _parent_key=key)
#     544
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in create(object_name, *args, **kwargs)
#     792         if class_name in ['Figure', 'Data', 'Frames']:
# --> 793             return globals()[class_name](*args, **kwargs)
#     794         else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#     157         for index, value in enumerate(list(*args)):
# --> 158             value = self._value_to_graph_object(index, value, _raise=_raise)
#     159
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in _value_to_graph_object(self, index, value, _raise)
#    1071                 path = self._get_path() + (0, )
# -> 1072                 raise exceptions.PlotlyDataTypeError(self, path)
#    1073
#
# PlotlyDataTypeError: Invalid entry found in 'data' at index, '0'
#
# Path To Error: ['data'][0]
#
# It's invalid because it doesn't contain a valid 'type' value.
#
# During handling of the above exception, another exception occurred:
#
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-108-1acf001bedba> in <module>()
#       1 fig = dict(data=data, layout=layout)
# ----> 2 py.iplot(fig)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     199
#     200     """
# --> 201     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     202     for entry in figure['data']:
#     203         if ('type' in entry) and (entry['type'] == 'scattergl'):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1462                                          "plot option.\nHere's why you're "
#    1463                                          "seeing this error:\n\n{0}"
# -> 1464                                          "".format(err))
#    1465         if not figure['data']:
#    1466             raise exceptions.PlotlyEmptyDataError(
#
# PlotlyError: Invalid 'figure_or_data' argument. Plotly will not be able to properly parse the resulting JSON. If you want to send this 'figure_or_data' to Plotly anyway (not recommended), you can set 'validate=False' as a plot option.
# Here's why you're seeing this error:
#
# Invalid entry found in 'data' at index, '0'
#
# Path To Error: ['data'][0]
#
# It's invalid because it doesn't contain a valid 'type' value.

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
py.iplot(table)

# %%
import plotly.plotly as py
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df.head()
import plotly.plotly as py
from plotly.graph_objs import *

import pandas as pd

mapbox_access_token = 'pk.eyJ1IjoieXVoMTMiLCJhIjoiY2pmZzdxejhvMmYyMzMzcGFybXk5cWtyaSJ9.eZ2saewGIMq6Z4vmd6j1zQ'

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/Nuclear%20Waste%20Sites%20on%20American%20Campuses.csv')
site_lat = df.lat
site_lon = df.lon
locations_name = df.text

data = Data([
    Scattermapbox(
        lat=site_lat,
        lon=site_lon,
        mode='markers',
        marker=Marker(
            size=17,
            color='rgb(255, 0, 0)',
            opacity=0.7
        ),
        text=locations_name,
        hoverinfo='text'
    ),
    Scattermapbox(
        lat=site_lat,
        lon=site_lon,
        mode='markers',
        marker=Marker(
            size=8,
            color='rgb(242, 177, 172)',
            opacity=0.7
        ),
        hoverinfo='none'
    )]
)
        
layout = Layout(
    title='Nuclear Waste Sites on Campus',
    autosize=True,
    hovermode='closest',
    showlegend=False,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=38,
            lon=-94
        ),
        pitch=0,
        zoom=3,
        style='light'
    ),
)

fig = dict(data=data, layout=layout)

py.iplot(fig)

# %%
import plotly.plotly as py
from plotly.graph_objs import *

import pandas as pd

mapbox_access_token = 'pk.eyJ1IjoieXVoMTMiLCJhIjoiY2pmZzdxejhvMmYyMzMzcGFybXk5cWtyaSJ9.eZ2saewGIMq6Z4vmd6j1zQ'

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/Nuclear%20Waste%20Sites%20on%20American%20Campuses.csv')
site_lat = df.lat
site_lon = df.lon
locations_name = df.text

data = Data([
    Scattermapbox(
        lat=site_lat,
        lon=site_lon,
        mode='markers',
        marker=Marker(
            size=17,
            color='rgb(255, 0, 0)',
            opacity=0.7
        ),
        text=locations_name,
        hoverinfo='text'
    ),
    Scattermapbox(
        lat=site_lat,
        lon=site_lon,
        mode='markers',
        marker=Marker(
            size=8,
            color='rgb(242, 177, 172)',
            opacity=0.7
        ),
        hoverinfo='none'
    )]
)
        
layout = Layout(
    title='Nuclear Waste Sites on Campus',
    autosize=True,
    hovermode='closest',
    showlegend=False,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=38,
            lon=-94
        ),
        pitch=0,
        zoom=3,
        style='light'
    ),
)

fig = dict(data=data, layout=layout)

py.iplot(fig, filename='jupyter/Nuclear Waste Sites on American Campuses')
