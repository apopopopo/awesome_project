# %%
import pandas as pd
hospital_df=pd.read_csv("hospital_charges_numeric.csv")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
del hospital_df[hospital_df.columns[0]]
hospital_df
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
# 5       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10023
# 6       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10029
# 7       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10033
# 8       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10039
# 9       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10040
# 10      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10046
# 11      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10055
# 12      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10056
# 13      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10078
# ...

# %%
hospital_df.columns
# Out:
# Index(['DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Hospital Referral Region Description',
#        ' Total Discharges ', ' Average Covered Charges ',
#        ' Average Total Payments ', 'Average Medicare Payments'],
#       dtype='object')

# %%
hospital_df['Hospital Referral Region Description']=hospital_df['Hospital Referral Region Description'].str.split(' - ').apply(lambda x: x[-1])
hospital_df=hospital_df.rename(columns={"Hospital Referral Region Description":"County name"})
hospital_df
# ["County name"].unique()
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
# 5       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10023
# 6       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10029
# 7       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10033
# 8       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10039
# 9       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10040
# 10      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10046
# 11      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10055
# 12      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10056
# 13      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10078
# ...

# %%
Max_county_df=pd.read_csv("Max_county.csv")
Max_county_df['County name']=Max_county_df['County name'].str.split(', ').apply(lambda x: x[0])
Max_county_df['County name']=Max_county_df['County name'].str.split('County').apply(lambda x: x[0])
del Max_county_df[Max_county_df.columns[0]]
Max_county_df
# Out:
#             County name Pop/mile2 Pop/km2
# 0             New York     69,468  26,822
# 1                Kings     35,369  13,656
# 2                Bronx     32,903  12,704
# 3               Queens     20,554   7,936
# 4        San Francisco     17,179   6,633
# 5               Hudson     13,732   5,302
# 6              Suffolk     12,417   4,794
# 7         Philadelphia     11,379   4,394
# 8            Washington     9,857   3,806
# 9            Alexandria     9,314   3,596
# 10            Richmond      8,030   3,101
# 11           Arlington      7,994   3,086
# 12    City of Baltimore     7,672   2,962
# 13               Essex      6,212   2,398
# 14         Falls Church     6,170   2,382
# 15        Manassas Park     5,633   2,175
# 16                Cook      5,495   2,122
# 17               Union      5,216   2,014
# 18  City of Saint Louis     5,157   1,991
# 19              Nassau      4,705   1,817
# 20              Norfolk     4,486   1,732
# ...

# %%
# Out:
#                                          DRG Definition  Provider Id  \
# 0              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        90001
# 1              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        90004
# 2              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        90011
# 3              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       210001
# 4              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       210005
# 5              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       210022
# 6              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       210023
# 7              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       210027
# 8              039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       210057
# 9     057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...        90001
# 10    057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...        90004
# 11    057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...        90006
# 12    057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...        90011
# ...

# %%
merge_county_max.columns
# Out:
# Index(['DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'County name', ' Total Discharges ',
#        ' Average Covered Charges ', ' Average Total Payments ',
#        'Average Medicare Payments', 'Pop/mile2', 'Pop/km2'],
#       dtype='object')

# %%
Average=merge_county_max[' Average Covered Charges ']
Population=merge_county_max['Pop/mile2']
plt.scatter(Average,Population)
plt.xlabel("Average cost")
plt.ylabel("Density")
